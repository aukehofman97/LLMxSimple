# %%
import json
import networkx as nx
import matplotlib.pyplot as plt
import csv
import re

# %%
def json_to_graph(data, graph=None, parent=None):
    """
    Recursively traverse a JSON structure and create a graph with nodes and edges.

    Parameters:
    - data: dict or list, the JSON data to be processed
    - graph: nx.Graph or nx.DiGraph, the graph being built
    - parent: str, the parent node (if any) for creating edges

    Returns:
    - graph: a NetworkX graph representing the JSON structure.
    """
    if graph is None:
        graph = nx.DiGraph()

    if isinstance(data, dict):
        for key, value in data.items():
            if value is None or value == "":
                continue

            node_id = f"{parent}.{key}" if parent else key
            # Include the key as the label (preserve index notation if present)
            label = key.split('[')[0] + key[key.find('['):] if '[' in key else key
            graph.add_node(node_id, label=label, value=str(value))
            
            if parent:
                graph.add_edge(parent, node_id, relation="contains")
            
            json_to_graph(value, graph, node_id)
    
    elif isinstance(data, list):
        for index, item in enumerate(data):
            if item is None or item == "":
                continue

            node_id = f"{parent}[{index}]" if parent else f"[{index}]"
            label = parent.split('.')[-1] + f"[{index}]"
            graph.add_node(node_id, label=label, value=str(item))
            
            if parent:
                graph.add_edge(parent, node_id, relation="contains")
            
            json_to_graph(item, graph, node_id)
    
    else:
        if data is None or data == "":
            return graph

        node_id = str(parent)
        label = parent.split('.')[-1] if parent else "root"
        graph.add_node(node_id, label=label, value=str(data))
        if parent:
            graph.add_edge(parent.rsplit('.', 1)[0], node_id, relation="contains")
    
    return graph

# %%
def json_to_graph_keep_deepest(data, graph=None, parent=None):
    """
    Recursively traverse a JSON structure and create a graph with only the deepest literal nodes.

    Parameters:
    - data: dict or list, the JSON data to be processed
    - graph: nx.Graph or nx.DiGraph, the graph being built
    - parent: str, the parent node (if any) for creating edges

    Returns:
    - graph: a NetworkX graph with only the deepest literal values.
    """
    if graph is None:
        graph = nx.DiGraph()

    if isinstance(data, dict):
        is_leaf = True
        for key, value in data.items():
            if isinstance(value, (dict, list)):
                is_leaf = False
                json_to_graph_keep_deepest(value, graph, f"{parent}.{key}" if parent else key)
            elif value is not None and value != "":
                is_leaf = False
                node_id = f"{parent}.{key}" if parent else key
                # Include the key as the label (preserve index notation if present)
                label = key.split('[')[0] + key[key.find('['):] if '[' in key else key
                graph.add_node(node_id, label=label, value=str(value))
                if parent:
                    graph.add_edge(parent, node_id, relation="contains")

        if is_leaf and parent and parent in graph:
            graph.remove_node(parent)

    elif isinstance(data, list):
        is_leaf = True
        for index, item in enumerate(data):
            if isinstance(item, (dict, list)):
                is_leaf = False
                json_to_graph_keep_deepest(item, graph, f"{parent}[{index}]" if parent else f"[{index}]")
            elif item is not None and item != "":
                is_leaf = False
                node_id = f"{parent}[{index}]" if parent else f"[{index}]"
                label = parent.split('.')[-1] + f"[{index}]"
                graph.add_node(node_id, label=label, value=str(item))
                if parent:
                    graph.add_edge(parent, node_id, relation="contains")

        if is_leaf and parent and parent in graph:
            graph.remove_node(parent)

    else:
        if data is not None and data != "":
            node_id = parent
            label = parent.split('.')[-1] if parent else "root"
            graph.add_node(node_id, label=label, value=str(data))
            if parent:
                graph.add_edge(parent.rsplit('.', 1)[0], node_id, relation="contains")

    return graph

# %%
json_data = {
    "messageType": "eventDetailed",
    "message": {
        "externalShipmentId": None,
        "externalConsignmentId": "222",
        "externalEventId": "53",
        "place": {
            "placeLocalization": {
                "addressName": None,
                "addressNumber": None,
                "location": None,
                "roadType": None,
                "terminalNode": {
                    "nodeCode": "62105",
                    "nodeName": None
                }
            },
            "dateTimeType": {
                "dateTime": "2024-06-17T17:15:00.000+02:00",
                "type": "Actual"
            }
        },
        "externalOrderId": None,
        "eventType": "ARRIVAL_EVENT",
        "equipments": None,
        "transportMean": None,
        "observations": None,
        "externalReferences": [
            {
                "type": "event_reference",
                "id": "E-00001",
                "endPoint": None
            }
        ]
    },
    "operationType": "CREATE"
}

# Generate the graph
G = json_to_graph(json_data)
G2 = json_to_graph_keep_deepest(json_data)

# %%
json_data = {
	"messageType": "shipmentDetailed",
	"message": {
		"externalShipmentId": "ES24D44444444FXHCUHCT",
		"contractCarriageCondition": "NA",
		"involvedActors": [
			{
				"actorAddress": None,
				"actorId": "D44444444",
				"actorName": "Company D",
				"actorRoles": [
					"LogisticRoles_TransportOperator"
				],
				"actorWebSite": None,
				"actorEmail": "Simple4shipment@gmail.com",
				"actorPhoneNumber": None
			},
			{
				"actorAddress": None,
				"actorId": "A11111111",
				"actorName": "Company B",
				"actorRoles": [
					"LogisticRoles_Consignor"
				],
				"actorWebSite": None,
				"actorEmail": None,
				"actorPhoneNumber": None
			},
			{
				"actorAddress": None,
				"actorId": "B22222222",
				"actorName": "Company A",
				"actorRoles": [
					"LogisticRoles_Consignee"
				],
				"actorWebSite": None,
				"actorEmail": "Juavie10@gmail.com",
				"actorPhoneNumber": None
			},
			{
				"actorAddress": None,
				"actorId": "C33333333",
				"actorName": "Company C",
				"actorRoles": [
					"LogisticRoles_DispatchParty"
				],
				"actorWebSite": None,
				"actorEmail": None,
				"actorPhoneNumber": None
			}
		],
		"origin": {
			"placeLocalization": {
				"addressName": None,
				"addressNumber": None,
				"location": {
					"zipCode": None,
					"city": {
						"name": None,
						"cityLoCode": "ES MAD"
					},
					"country": {
						"name": None,
						"unLoCode": "ES"
					}
				},
				"roadType": None,
				"terminalNode": None
			},
			"dateTimeType": {
				"dateTime": "2024-09-16T11:46:45.000+02:00",
				"type": "Estimated"
			}
		},
		"destination": {
			"placeLocalization": {
				"addressName": None,
				"addressNumber": None,
				"location": {
					"zipCode": None,
					"city": {
						"name": None,
						"cityLoCode": "ES SVQ"
					},
					"country": {
						"name": None,
						"unLoCode": "ES"
					}
				},
				"roadType": None,
				"terminalNode": None
			},
			"dateTimeType": {
				"dateTime": "2024-09-23T13:15:48.000+02:00",
				"type": "Estimated"
			}
		},
		"equipments": [
			{
				"equipmentId": "JSVU12453627",
				"equipmentType": {
					"code": "CN",
					"description": None
				},
				"wagonId": None,
				"codeITU": "40",
				"grossWeight": 42000,
				"isEmpty": True,
				"sealIndicator": "Precxx3234",
				"goods": [
					{
						"package": {
							"numberOfPackages": 26,
							"shippingMark": "bridgestones",
							"packagingType": None
						},
						"goodTypeCode": "tires",
						"goodDescription": "finished rubber tires",
						"cargoType": "Pallets",
						"idNumberList": [
							"21321"
						],
						"goodWeight": 0.0,
						"goodGrossMass": 23000.0,
						"goodSize": 12,
						"temperature": None,
						"dangerousGoods": False,
						"dangerousGoodsDescription": None,
						"damageRemarks": None
					}
				],
				"damageRemarks": "string",
				"city": {
					"name": None,
					"cityLoCode": "ES MAD"
				},
				"country": None,
				"dangerousEquipment": False,
				"dangerousEquipmentDescription": None
			}
		],
		"documents": [],
		"externalReferences": [
			{
				"type": "shipment_reference",
				"id": "BL112233",
				"endPoint": None
			}
		]
	},
	"operationType": "CREATE"
}
# Generate the graph
G = json_to_graph(json_data)
G2 = json_to_graph_keep_deepest(json_data)

# %%
flowertrucks_json_data = {
    "messageType": "Transport Opdracht",
    "message": {
        "shipment": {
            "shipper": "Asian Export Food",
            "loadingLocation": {
                "plaats": "Kampen",
                "land": "Nederland"
            },
            "loadingDate": "17-01-2025"
        },
        "goods": [
            {
                "kenmerk": "00803055558",
                "actie": "Lossen",
                "euroDV": 1,
                "blokDV": 1,
                "noOfColli": 23,
                "unloadLocation": {
                    "straat": "Masvagen 2",
                    "naam": "AX Utveckling AB",
                    "postcode": "22100",
                    "plaats": "MARIEHAMN",
                    "land": "FIN"
                }
            },
            {
                "kenmerk": "00803055544",
                "actie": "Lossen",
                "euroDV": 1,
                "blokDV": 1,
                "noOfColli": 16,
                "unloadLocation": {
                    "straat": "Hämeenkatu 7",
                    "naam": "Nurmi Dao Oy",
                    "postcode": "20500",
                    "plaats": "TURKU",
                    "land": "FIN"
                }
            },
            {
                "kenmerk": "0080305561",
                "actie": "Lossen",
                "euroDV": 1,
                "blokDV": 1,
                "noOfColli": 1,
                "unloadLocation": {
                    "straat": "Kuunsade 10b 43",
                    "naam": "Golden Food Oy",
                    "postcode": "02210",
                    "plaats": "HELSINKI",
                    "land": "FIN"
                }
            },
            {
                "kenmerk": "00803055599",
                "actie": "Lossen",
                "euroDV": 2,
                "blokDV": 3,
                "noOfColli": 50,
                "unloadLocation": {
                    "straat": "Gatan 5",
                    "naam": "ABC Logistics",
                    "postcode": "11450",
                    "plaats": "STOCKHOLM",
                    "land": "SWE"
                }
            },
            {
                "kenmerk": "0080305560",
                "actie": "Lossen",
                "euroDV": 1,
                "blokDV": 2,
                "noOfColli": 12,
                "unloadLocation": {
                    "straat": "Storgata 15",
                    "naam": "Nordic Foods",
                    "postcode": "0161",
                    "plaats": "OSLO",
                    "land": "NOR"
                }
            },
            {
                "kenmerk": "0080305562",
                "actie": "Lossen",
                "euroDV": 2,
                "blokDV": 3,
                "noOfColli": 25,
                "unloadLocation": {
                    "straat": "Skolgatan 12",
                    "naam": "Food Service AB",
                    "postcode": "11850",
                    "plaats": "GOTHENBURG",
                    "land": "SWE"
                }
            },
            {
                "kenmerk": "0080305563",
                "actie": "Lossen",
                "euroDV": 1,
                "blokDV": 2,
                "noOfColli": 10,
                "unloadLocation": {
                    "straat": "Bryggen 3",
                    "naam": "North Sea Logistics",
                    "postcode": "5003",
                    "plaats": "BERGEN",
                    "land": "NOR"
                }
            },
            {
                "kenmerk": "0080305564",
                "actie": "Lossen",
                "euroDV": 2,
                "blokDV": 1,
                "noOfColli": 8,
                "unloadLocation": {
                    "straat": "Tallinn Road 8",
                    "naam": "Baltic Foods",
                    "postcode": "10111",
                    "plaats": "TALLINN",
                    "land": "EST"
                }
            },
            {
                "kenmerk": "0080305565",
                "actie": "Lossen",
                "euroDV": 2,
                "blokDV": 3,
                "noOfColli": 18,
                "unloadLocation": {
                    "straat": "Main Street 22",
                    "naam": "Global Goods Inc",
                    "postcode": "8000",
                    "plaats": "AARHUS",
                    "land": "DNK"
                }
            },
            {
                "kenmerk": "0080305566",
                "actie": "Lossen",
                "euroDV": 1,
                "blokDV": 2,
                "noOfColli": 15,
                "unloadLocation": {
                    "straat": "Food Street 45",
                    "naam": "ScandiFoods AS",
                    "postcode": "3010",
                    "plaats": "DRAMMEN",
                    "land": "NOR"
                }
            }
        ]
    }
}
# Generate the graph
Flowertrucks_G = json_to_graph(flowertrucks_json_data)
Flowertrucks_G2 = json_to_graph_keep_deepest(flowertrucks_json_data)

# %%
# List all nodes with their attributes
print("Nodes:")
for node, attributes in Flowertrucks_G.nodes(data=True):
    print(f"  {node}: {attributes}")

# List all edges with their relationships
print("\nEdges:")
for source, target, attributes in Flowertrucks_G.edges(data=True):
    print(f"  {source} -> {target} [relation: {attributes['relation']}]")
# Out:
# Nodes:
#   messageType: {'label': 'messageType', 'value': 'Transport Opdracht'}
#   message: {'label': 'message', 'value': "{'shipment': {'shipper': 'Asian Export Food', 'loadingLocation': {'plaats': 'Kampen', 'land': 'Nederland'}, 'loadingDate': '17-01-2025'}, 'goods': [{'kenmerk': '00803055558', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 1, 'noOfColli': 23, 'unloadLocation': {'straat': 'Masvagen 2', 'naam': 'AX Utveckling AB', 'postcode': '22100', 'plaats': 'MARIEHAMN', 'land': 'FIN'}}, {'kenmerk': '00803055544', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 1, 'noOfColli': 16, 'unloadLocation': {'straat': 'Hämeenkatu 7', 'naam': 'Nurmi Dao Oy', 'postcode': '20500', 'plaats': 'TURKU', 'land': 'FIN'}}, {'kenmerk': '0080305561', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 1, 'noOfColli': 1, 'unloadLocation': {'straat': 'Kuunsade 10b 43', 'naam': 'Golden Food Oy', 'postcode': '02210', 'plaats': 'HELSINKI', 'land': 'FIN'}}, {'kenmerk': '00803055599', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 3, 'noOfColli': 50, 'unloadLocation': {'straat': 'Gatan 5', 'naam': 'ABC Logistics', 'postcode': '11450', 'plaats': 'STOCKHOLM', 'land': 'SWE'}}, {'kenmerk': '0080305560', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 2, 'noOfColli': 12, 'unloadLocation': {'straat': 'Storgata 15', 'naam': 'Nordic Foods', 'postcode': '0161', 'plaats': 'OSLO', 'land': 'NOR'}}, {'kenmerk': '0080305562', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 3, 'noOfColli': 25, 'unloadLocation': {'straat': 'Skolgatan 12', 'naam': 'Food Service AB', 'postcode': '11850', 'plaats': 'GOTHENBURG', 'land': 'SWE'}}, {'kenmerk': '0080305563', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 2, 'noOfColli': 10, 'unloadLocation': {'straat': 'Bryggen 3', 'naam': 'North Sea Logistics', 'postcode': '5003', 'plaats': 'BERGEN', 'land': 'NOR'}}, {'kenmerk': '0080305564', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 1, 'noOfColli': 8, 'unloadLocation': {'straat': 'Tallinn Road 8', 'naam': 'Baltic Foods', 'postcode': '10111', 'plaats': 'TALLINN', 'land': 'EST'}}, {'kenmerk': '0080305565', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 3, 'noOfColli': 18, 'unloadLocation': {'straat': 'Main Street 22', 'naam': 'Global Goods Inc', 'postcode': '8000', 'plaats': 'AARHUS', 'land': 'DNK'}}, {'kenmerk': '0080305566', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 2, 'noOfColli': 15, 'unloadLocation': {'straat': 'Food Street 45', 'naam': 'ScandiFoods AS', 'postcode': '3010', 'plaats': 'DRAMMEN', 'land': 'NOR'}}]}"}
#   message.shipment: {'label': 'shipment', 'value': "{'shipper': 'Asian Export Food', 'loadingLocation': {'plaats': 'Kampen', 'land': 'Nederland'}, 'loadingDate': '17-01-2025'}"}
#   message.shipment.shipper: {'label': 'shipper', 'value': 'Asian Export Food'}
#   message.shipment.loadingLocation: {'label': 'loadingLocation', 'value': "{'plaats': 'Kampen', 'land': 'Nederland'}"}
#   message.shipment.loadingLocation.plaats: {'label': 'plaats', 'value': 'Kampen'}
#   message.shipment.loadingLocation.land: {'label': 'land', 'value': 'Nederland'}
#   message.shipment.loadingDate: {'label': 'loadingDate', 'value': '17-01-2025'}
#   message.goods: {'label': 'goods', 'value': "[{'kenmerk': '00803055558', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 1, 'noOfColli': 23, 'unloadLocation': {'straat': 'Masvagen 2', 'naam': 'AX Utveckling AB', 'postcode': '22100', 'plaats': 'MARIEHAMN', 'land': 'FIN'}}, {'kenmerk': '00803055544', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 1, 'noOfColli': 16, 'unloadLocation': {'straat': 'Hämeenkatu 7', 'naam': 'Nurmi Dao Oy', 'postcode': '20500', 'plaats': 'TURKU', 'land': 'FIN'}}, {'kenmerk': '0080305561', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 1, 'noOfColli': 1, 'unloadLocation': {'straat': 'Kuunsade 10b 43', 'naam': 'Golden Food Oy', 'postcode': '02210', 'plaats': 'HELSINKI', 'land': 'FIN'}}, {'kenmerk': '00803055599', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 3, 'noOfColli': 50, 'unloadLocation': {'straat': 'Gatan 5', 'naam': 'ABC Logistics', 'postcode': '11450', 'plaats': 'STOCKHOLM', 'land': 'SWE'}}, {'kenmerk': '0080305560', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 2, 'noOfColli': 12, 'unloadLocation': {'straat': 'Storgata 15', 'naam': 'Nordic Foods', 'postcode': '0161', 'plaats': 'OSLO', 'land': 'NOR'}}, {'kenmerk': '0080305562', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 3, 'noOfColli': 25, 'unloadLocation': {'straat': 'Skolgatan 12', 'naam': 'Food Service AB', 'postcode': '11850', 'plaats': 'GOTHENBURG', 'land': 'SWE'}}, {'kenmerk': '0080305563', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 2, 'noOfColli': 10, 'unloadLocation': {'straat': 'Bryggen 3', 'naam': 'North Sea Logistics', 'postcode': '5003', 'plaats': 'BERGEN', 'land': 'NOR'}}, {'kenmerk': '0080305564', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 1, 'noOfColli': 8, 'unloadLocation': {'straat': 'Tallinn Road 8', 'naam': 'Baltic Foods', 'postcode': '10111', 'plaats': 'TALLINN', 'land': 'EST'}}, {'kenmerk': '0080305565', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 3, 'noOfColli': 18, 'unloadLocation': {'straat': 'Main Street 22', 'naam': 'Global Goods Inc', 'postcode': '8000', 'plaats': 'AARHUS', 'land': 'DNK'}}, {'kenmerk': '0080305566', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 2, 'noOfColli': 15, 'unloadLocation': {'straat': 'Food Street 45', 'naam': 'ScandiFoods AS', 'postcode': '3010', 'plaats': 'DRAMMEN', 'land': 'NOR'}}]"}
#   message.goods[0]: {'label': 'goods[0]', 'value': "{'kenmerk': '00803055558', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 1, 'noOfColli': 23, 'unloadLocation': {'straat': 'Masvagen 2', 'naam': 'AX Utveckling AB', 'postcode': '22100', 'plaats': 'MARIEHAMN', 'land': 'FIN'}}"}
#   message.goods[0].kenmerk: {'label': 'kenmerk', 'value': '00803055558'}
#   message.goods[0].actie: {'label': 'actie', 'value': 'Lossen'}
#   message.goods[0].euroDV: {'label': 'euroDV', 'value': '1'}
#   message.goods[0].blokDV: {'label': 'blokDV', 'value': '1'}
#   message.goods[0].noOfColli: {'label': 'noOfColli', 'value': '23'}
#   message.goods[0].unloadLocation: {'label': 'unloadLocation', 'value': "{'straat': 'Masvagen 2', 'naam': 'AX Utveckling AB', 'postcode': '22100', 'plaats': 'MARIEHAMN', 'land': 'FIN'}"}
#   message.goods[0].unloadLocation.straat: {'label': 'straat', 'value': 'Masvagen 2'}
#   message.goods[0].unloadLocation.naam: {'label': 'naam', 'value': 'AX Utveckling AB'}
#   message.goods[0].unloadLocation.postcode: {'label': 'postcode', 'value': '22100'}
#   message.goods[0].unloadLocation.plaats: {'label': 'plaats', 'value': 'MARIEHAMN'}
#   message.goods[0].unloadLocation.land: {'label': 'land', 'value': 'FIN'}
#   message.goods[1]: {'label': 'goods[1]', 'value': "{'kenmerk': '00803055544', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 1, 'noOfColli': 16, 'unloadLocation': {'straat': 'Hämeenkatu 7', 'naam': 'Nurmi Dao Oy', 'postcode': '20500', 'plaats': 'TURKU', 'land': 'FIN'}}"}
#   message.goods[1].kenmerk: {'label': 'kenmerk', 'value': '00803055544'}
#   message.goods[1].actie: {'label': 'actie', 'value': 'Lossen'}
#   message.goods[1].euroDV: {'label': 'euroDV', 'value': '1'}
#   message.goods[1].blokDV: {'label': 'blokDV', 'value': '1'}
#   message.goods[1].noOfColli: {'label': 'noOfColli', 'value': '16'}
#   message.goods[1].unloadLocation: {'label': 'unloadLocation', 'value': "{'straat': 'Hämeenkatu 7', 'naam': 'Nurmi Dao Oy', 'postcode': '20500', 'plaats': 'TURKU', 'land': 'FIN'}"}
#   message.goods[1].unloadLocation.straat: {'label': 'straat', 'value': 'Hämeenkatu 7'}
#   message.goods[1].unloadLocation.naam: {'label': 'naam', 'value': 'Nurmi Dao Oy'}
#   message.goods[1].unloadLocation.postcode: {'label': 'postcode', 'value': '20500'}
#   message.goods[1].unloadLocation.plaats: {'label': 'plaats', 'value': 'TURKU'}
#   message.goods[1].unloadLocation.land: {'label': 'land', 'value': 'FIN'}
#   message.goods[2]: {'label': 'goods[2]', 'value': "{'kenmerk': '0080305561', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 1, 'noOfColli': 1, 'unloadLocation': {'straat': 'Kuunsade 10b 43', 'naam': 'Golden Food Oy', 'postcode': '02210', 'plaats': 'HELSINKI', 'land': 'FIN'}}"}
#   message.goods[2].kenmerk: {'label': 'kenmerk', 'value': '0080305561'}
#   message.goods[2].actie: {'label': 'actie', 'value': 'Lossen'}
#   message.goods[2].euroDV: {'label': 'euroDV', 'value': '1'}
#   message.goods[2].blokDV: {'label': 'blokDV', 'value': '1'}
#   message.goods[2].noOfColli: {'label': 'noOfColli', 'value': '1'}
#   message.goods[2].unloadLocation: {'label': 'unloadLocation', 'value': "{'straat': 'Kuunsade 10b 43', 'naam': 'Golden Food Oy', 'postcode': '02210', 'plaats': 'HELSINKI', 'land': 'FIN'}"}
#   message.goods[2].unloadLocation.straat: {'label': 'straat', 'value': 'Kuunsade 10b 43'}
#   message.goods[2].unloadLocation.naam: {'label': 'naam', 'value': 'Golden Food Oy'}
#   message.goods[2].unloadLocation.postcode: {'label': 'postcode', 'value': '02210'}
#   message.goods[2].unloadLocation.plaats: {'label': 'plaats', 'value': 'HELSINKI'}
#   message.goods[2].unloadLocation.land: {'label': 'land', 'value': 'FIN'}
#   message.goods[3]: {'label': 'goods[3]', 'value': "{'kenmerk': '00803055599', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 3, 'noOfColli': 50, 'unloadLocation': {'straat': 'Gatan 5', 'naam': 'ABC Logistics', 'postcode': '11450', 'plaats': 'STOCKHOLM', 'land': 'SWE'}}"}
#   message.goods[3].kenmerk: {'label': 'kenmerk', 'value': '00803055599'}
#   message.goods[3].actie: {'label': 'actie', 'value': 'Lossen'}
#   message.goods[3].euroDV: {'label': 'euroDV', 'value': '2'}
#   message.goods[3].blokDV: {'label': 'blokDV', 'value': '3'}
#   message.goods[3].noOfColli: {'label': 'noOfColli', 'value': '50'}
#   message.goods[3].unloadLocation: {'label': 'unloadLocation', 'value': "{'straat': 'Gatan 5', 'naam': 'ABC Logistics', 'postcode': '11450', 'plaats': 'STOCKHOLM', 'land': 'SWE'}"}
#   message.goods[3].unloadLocation.straat: {'label': 'straat', 'value': 'Gatan 5'}
#   message.goods[3].unloadLocation.naam: {'label': 'naam', 'value': 'ABC Logistics'}
#   message.goods[3].unloadLocation.postcode: {'label': 'postcode', 'value': '11450'}
#   message.goods[3].unloadLocation.plaats: {'label': 'plaats', 'value': 'STOCKHOLM'}
#   message.goods[3].unloadLocation.land: {'label': 'land', 'value': 'SWE'}
#   message.goods[4]: {'label': 'goods[4]', 'value': "{'kenmerk': '0080305560', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 2, 'noOfColli': 12, 'unloadLocation': {'straat': 'Storgata 15', 'naam': 'Nordic Foods', 'postcode': '0161', 'plaats': 'OSLO', 'land': 'NOR'}}"}
#   message.goods[4].kenmerk: {'label': 'kenmerk', 'value': '0080305560'}
#   message.goods[4].actie: {'label': 'actie', 'value': 'Lossen'}
#   message.goods[4].euroDV: {'label': 'euroDV', 'value': '1'}
#   message.goods[4].blokDV: {'label': 'blokDV', 'value': '2'}
#   message.goods[4].noOfColli: {'label': 'noOfColli', 'value': '12'}
#   message.goods[4].unloadLocation: {'label': 'unloadLocation', 'value': "{'straat': 'Storgata 15', 'naam': 'Nordic Foods', 'postcode': '0161', 'plaats': 'OSLO', 'land': 'NOR'}"}
#   message.goods[4].unloadLocation.straat: {'label': 'straat', 'value': 'Storgata 15'}
#   message.goods[4].unloadLocation.naam: {'label': 'naam', 'value': 'Nordic Foods'}
#   message.goods[4].unloadLocation.postcode: {'label': 'postcode', 'value': '0161'}
#   message.goods[4].unloadLocation.plaats: {'label': 'plaats', 'value': 'OSLO'}
#   message.goods[4].unloadLocation.land: {'label': 'land', 'value': 'NOR'}
#   message.goods[5]: {'label': 'goods[5]', 'value': "{'kenmerk': '0080305562', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 3, 'noOfColli': 25, 'unloadLocation': {'straat': 'Skolgatan 12', 'naam': 'Food Service AB', 'postcode': '11850', 'plaats': 'GOTHENBURG', 'land': 'SWE'}}"}
#   message.goods[5].kenmerk: {'label': 'kenmerk', 'value': '0080305562'}
#   message.goods[5].actie: {'label': 'actie', 'value': 'Lossen'}
#   message.goods[5].euroDV: {'label': 'euroDV', 'value': '2'}
#   message.goods[5].blokDV: {'label': 'blokDV', 'value': '3'}
#   message.goods[5].noOfColli: {'label': 'noOfColli', 'value': '25'}
#   message.goods[5].unloadLocation: {'label': 'unloadLocation', 'value': "{'straat': 'Skolgatan 12', 'naam': 'Food Service AB', 'postcode': '11850', 'plaats': 'GOTHENBURG', 'land': 'SWE'}"}
#   message.goods[5].unloadLocation.straat: {'label': 'straat', 'value': 'Skolgatan 12'}
#   message.goods[5].unloadLocation.naam: {'label': 'naam', 'value': 'Food Service AB'}
#   message.goods[5].unloadLocation.postcode: {'label': 'postcode', 'value': '11850'}
#   message.goods[5].unloadLocation.plaats: {'label': 'plaats', 'value': 'GOTHENBURG'}
#   message.goods[5].unloadLocation.land: {'label': 'land', 'value': 'SWE'}
#   message.goods[6]: {'label': 'goods[6]', 'value': "{'kenmerk': '0080305563', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 2, 'noOfColli': 10, 'unloadLocation': {'straat': 'Bryggen 3', 'naam': 'North Sea Logistics', 'postcode': '5003', 'plaats': 'BERGEN', 'land': 'NOR'}}"}
#   message.goods[6].kenmerk: {'label': 'kenmerk', 'value': '0080305563'}
#   message.goods[6].actie: {'label': 'actie', 'value': 'Lossen'}
#   message.goods[6].euroDV: {'label': 'euroDV', 'value': '1'}
#   message.goods[6].blokDV: {'label': 'blokDV', 'value': '2'}
#   message.goods[6].noOfColli: {'label': 'noOfColli', 'value': '10'}
#   message.goods[6].unloadLocation: {'label': 'unloadLocation', 'value': "{'straat': 'Bryggen 3', 'naam': 'North Sea Logistics', 'postcode': '5003', 'plaats': 'BERGEN', 'land': 'NOR'}"}
#   message.goods[6].unloadLocation.straat: {'label': 'straat', 'value': 'Bryggen 3'}
#   message.goods[6].unloadLocation.naam: {'label': 'naam', 'value': 'North Sea Logistics'}
#   message.goods[6].unloadLocation.postcode: {'label': 'postcode', 'value': '5003'}
#   message.goods[6].unloadLocation.plaats: {'label': 'plaats', 'value': 'BERGEN'}
#   message.goods[6].unloadLocation.land: {'label': 'land', 'value': 'NOR'}
#   message.goods[7]: {'label': 'goods[7]', 'value': "{'kenmerk': '0080305564', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 1, 'noOfColli': 8, 'unloadLocation': {'straat': 'Tallinn Road 8', 'naam': 'Baltic Foods', 'postcode': '10111', 'plaats': 'TALLINN', 'land': 'EST'}}"}
#   message.goods[7].kenmerk: {'label': 'kenmerk', 'value': '0080305564'}
#   message.goods[7].actie: {'label': 'actie', 'value': 'Lossen'}
#   message.goods[7].euroDV: {'label': 'euroDV', 'value': '2'}
#   message.goods[7].blokDV: {'label': 'blokDV', 'value': '1'}
#   message.goods[7].noOfColli: {'label': 'noOfColli', 'value': '8'}
#   message.goods[7].unloadLocation: {'label': 'unloadLocation', 'value': "{'straat': 'Tallinn Road 8', 'naam': 'Baltic Foods', 'postcode': '10111', 'plaats': 'TALLINN', 'land': 'EST'}"}
#   message.goods[7].unloadLocation.straat: {'label': 'straat', 'value': 'Tallinn Road 8'}
#   message.goods[7].unloadLocation.naam: {'label': 'naam', 'value': 'Baltic Foods'}
#   message.goods[7].unloadLocation.postcode: {'label': 'postcode', 'value': '10111'}
#   message.goods[7].unloadLocation.plaats: {'label': 'plaats', 'value': 'TALLINN'}
#   message.goods[7].unloadLocation.land: {'label': 'land', 'value': 'EST'}
#   message.goods[8]: {'label': 'goods[8]', 'value': "{'kenmerk': '0080305565', 'actie': 'Lossen', 'euroDV': 2, 'blokDV': 3, 'noOfColli': 18, 'unloadLocation': {'straat': 'Main Street 22', 'naam': 'Global Goods Inc', 'postcode': '8000', 'plaats': 'AARHUS', 'land': 'DNK'}}"}
#   message.goods[8].kenmerk: {'label': 'kenmerk', 'value': '0080305565'}
#   message.goods[8].actie: {'label': 'actie', 'value': 'Lossen'}
#   message.goods[8].euroDV: {'label': 'euroDV', 'value': '2'}
#   message.goods[8].blokDV: {'label': 'blokDV', 'value': '3'}
#   message.goods[8].noOfColli: {'label': 'noOfColli', 'value': '18'}
#   message.goods[8].unloadLocation: {'label': 'unloadLocation', 'value': "{'straat': 'Main Street 22', 'naam': 'Global Goods Inc', 'postcode': '8000', 'plaats': 'AARHUS', 'land': 'DNK'}"}
#   message.goods[8].unloadLocation.straat: {'label': 'straat', 'value': 'Main Street 22'}
#   message.goods[8].unloadLocation.naam: {'label': 'naam', 'value': 'Global Goods Inc'}
#   message.goods[8].unloadLocation.postcode: {'label': 'postcode', 'value': '8000'}
#   message.goods[8].unloadLocation.plaats: {'label': 'plaats', 'value': 'AARHUS'}
#   message.goods[8].unloadLocation.land: {'label': 'land', 'value': 'DNK'}
#   message.goods[9]: {'label': 'goods[9]', 'value': "{'kenmerk': '0080305566', 'actie': 'Lossen', 'euroDV': 1, 'blokDV': 2, 'noOfColli': 15, 'unloadLocation': {'straat': 'Food Street 45', 'naam': 'ScandiFoods AS', 'postcode': '3010', 'plaats': 'DRAMMEN', 'land': 'NOR'}}"}
#   message.goods[9].kenmerk: {'label': 'kenmerk', 'value': '0080305566'}
#   message.goods[9].actie: {'label': 'actie', 'value': 'Lossen'}
#   message.goods[9].euroDV: {'label': 'euroDV', 'value': '1'}
#   message.goods[9].blokDV: {'label': 'blokDV', 'value': '2'}
#   message.goods[9].noOfColli: {'label': 'noOfColli', 'value': '15'}
#   message.goods[9].unloadLocation: {'label': 'unloadLocation', 'value': "{'straat': 'Food Street 45', 'naam': 'ScandiFoods AS', 'postcode': '3010', 'plaats': 'DRAMMEN', 'land': 'NOR'}"}
#   message.goods[9].unloadLocation.straat: {'label': 'straat', 'value': 'Food Street 45'}
#   message.goods[9].unloadLocation.naam: {'label': 'naam', 'value': 'ScandiFoods AS'}
#   message.goods[9].unloadLocation.postcode: {'label': 'postcode', 'value': '3010'}
#   message.goods[9].unloadLocation.plaats: {'label': 'plaats', 'value': 'DRAMMEN'}
#   message.goods[9].unloadLocation.land: {'label': 'land', 'value': 'NOR'}
#
# Edges:
#   messageType -> messageType [relation: contains]
#   message -> message.shipment [relation: contains]
#   message -> message.goods [relation: contains]
#   message.shipment -> message.shipment.shipper [relation: contains]
#   message.shipment -> message.shipment.loadingLocation [relation: contains]
#   message.shipment -> message.shipment.loadingDate [relation: contains]
#   message.shipment.loadingLocation -> message.shipment.loadingLocation.plaats [relation: contains]
#   message.shipment.loadingLocation -> message.shipment.loadingLocation.land [relation: contains]
#   message.goods -> message.goods[0] [relation: contains]
#   message.goods -> message.goods[1] [relation: contains]
#   message.goods -> message.goods[2] [relation: contains]
#   message.goods -> message.goods[3] [relation: contains]
#   message.goods -> message.goods[4] [relation: contains]
#   message.goods -> message.goods[5] [relation: contains]
#   message.goods -> message.goods[6] [relation: contains]
#   message.goods -> message.goods[7] [relation: contains]
#   message.goods -> message.goods[8] [relation: contains]
#   message.goods -> message.goods[9] [relation: contains]
#   message.goods[0] -> message.goods[0].kenmerk [relation: contains]
#   message.goods[0] -> message.goods[0].actie [relation: contains]
#   message.goods[0] -> message.goods[0].euroDV [relation: contains]
#   message.goods[0] -> message.goods[0].blokDV [relation: contains]
#   message.goods[0] -> message.goods[0].noOfColli [relation: contains]
#   message.goods[0] -> message.goods[0].unloadLocation [relation: contains]
#   message.goods[0].unloadLocation -> message.goods[0].unloadLocation.straat [relation: contains]
#   message.goods[0].unloadLocation -> message.goods[0].unloadLocation.naam [relation: contains]
#   message.goods[0].unloadLocation -> message.goods[0].unloadLocation.postcode [relation: contains]
#   message.goods[0].unloadLocation -> message.goods[0].unloadLocation.plaats [relation: contains]
#   message.goods[0].unloadLocation -> message.goods[0].unloadLocation.land [relation: contains]
#   message.goods[1] -> message.goods[1].kenmerk [relation: contains]
#   message.goods[1] -> message.goods[1].actie [relation: contains]
#   message.goods[1] -> message.goods[1].euroDV [relation: contains]
#   message.goods[1] -> message.goods[1].blokDV [relation: contains]
#   message.goods[1] -> message.goods[1].noOfColli [relation: contains]
#   message.goods[1] -> message.goods[1].unloadLocation [relation: contains]
#   message.goods[1].unloadLocation -> message.goods[1].unloadLocation.straat [relation: contains]
#   message.goods[1].unloadLocation -> message.goods[1].unloadLocation.naam [relation: contains]
#   message.goods[1].unloadLocation -> message.goods[1].unloadLocation.postcode [relation: contains]
#   message.goods[1].unloadLocation -> message.goods[1].unloadLocation.plaats [relation: contains]
#   message.goods[1].unloadLocation -> message.goods[1].unloadLocation.land [relation: contains]
#   message.goods[2] -> message.goods[2].kenmerk [relation: contains]
#   message.goods[2] -> message.goods[2].actie [relation: contains]
#   message.goods[2] -> message.goods[2].euroDV [relation: contains]
#   message.goods[2] -> message.goods[2].blokDV [relation: contains]
#   message.goods[2] -> message.goods[2].noOfColli [relation: contains]
#   message.goods[2] -> message.goods[2].unloadLocation [relation: contains]
#   message.goods[2].unloadLocation -> message.goods[2].unloadLocation.straat [relation: contains]
#   message.goods[2].unloadLocation -> message.goods[2].unloadLocation.naam [relation: contains]
#   message.goods[2].unloadLocation -> message.goods[2].unloadLocation.postcode [relation: contains]
#   message.goods[2].unloadLocation -> message.goods[2].unloadLocation.plaats [relation: contains]
#   message.goods[2].unloadLocation -> message.goods[2].unloadLocation.land [relation: contains]
#   message.goods[3] -> message.goods[3].kenmerk [relation: contains]
#   message.goods[3] -> message.goods[3].actie [relation: contains]
#   message.goods[3] -> message.goods[3].euroDV [relation: contains]
#   message.goods[3] -> message.goods[3].blokDV [relation: contains]
#   message.goods[3] -> message.goods[3].noOfColli [relation: contains]
#   message.goods[3] -> message.goods[3].unloadLocation [relation: contains]
#   message.goods[3].unloadLocation -> message.goods[3].unloadLocation.straat [relation: contains]
#   message.goods[3].unloadLocation -> message.goods[3].unloadLocation.naam [relation: contains]
#   message.goods[3].unloadLocation -> message.goods[3].unloadLocation.postcode [relation: contains]
#   message.goods[3].unloadLocation -> message.goods[3].unloadLocation.plaats [relation: contains]
#   message.goods[3].unloadLocation -> message.goods[3].unloadLocation.land [relation: contains]
#   message.goods[4] -> message.goods[4].kenmerk [relation: contains]
#   message.goods[4] -> message.goods[4].actie [relation: contains]
#   message.goods[4] -> message.goods[4].euroDV [relation: contains]
#   message.goods[4] -> message.goods[4].blokDV [relation: contains]
#   message.goods[4] -> message.goods[4].noOfColli [relation: contains]
#   message.goods[4] -> message.goods[4].unloadLocation [relation: contains]
#   message.goods[4].unloadLocation -> message.goods[4].unloadLocation.straat [relation: contains]
#   message.goods[4].unloadLocation -> message.goods[4].unloadLocation.naam [relation: contains]
#   message.goods[4].unloadLocation -> message.goods[4].unloadLocation.postcode [relation: contains]
#   message.goods[4].unloadLocation -> message.goods[4].unloadLocation.plaats [relation: contains]
#   message.goods[4].unloadLocation -> message.goods[4].unloadLocation.land [relation: contains]
#   message.goods[5] -> message.goods[5].kenmerk [relation: contains]
#   message.goods[5] -> message.goods[5].actie [relation: contains]
#   message.goods[5] -> message.goods[5].euroDV [relation: contains]
#   message.goods[5] -> message.goods[5].blokDV [relation: contains]
#   message.goods[5] -> message.goods[5].noOfColli [relation: contains]
#   message.goods[5] -> message.goods[5].unloadLocation [relation: contains]
#   message.goods[5].unloadLocation -> message.goods[5].unloadLocation.straat [relation: contains]
#   message.goods[5].unloadLocation -> message.goods[5].unloadLocation.naam [relation: contains]
#   message.goods[5].unloadLocation -> message.goods[5].unloadLocation.postcode [relation: contains]
#   message.goods[5].unloadLocation -> message.goods[5].unloadLocation.plaats [relation: contains]
#   message.goods[5].unloadLocation -> message.goods[5].unloadLocation.land [relation: contains]
#   message.goods[6] -> message.goods[6].kenmerk [relation: contains]
#   message.goods[6] -> message.goods[6].actie [relation: contains]
#   message.goods[6] -> message.goods[6].euroDV [relation: contains]
#   message.goods[6] -> message.goods[6].blokDV [relation: contains]
#   message.goods[6] -> message.goods[6].noOfColli [relation: contains]
#   message.goods[6] -> message.goods[6].unloadLocation [relation: contains]
#   message.goods[6].unloadLocation -> message.goods[6].unloadLocation.straat [relation: contains]
#   message.goods[6].unloadLocation -> message.goods[6].unloadLocation.naam [relation: contains]
#   message.goods[6].unloadLocation -> message.goods[6].unloadLocation.postcode [relation: contains]
#   message.goods[6].unloadLocation -> message.goods[6].unloadLocation.plaats [relation: contains]
#   message.goods[6].unloadLocation -> message.goods[6].unloadLocation.land [relation: contains]
#   message.goods[7] -> message.goods[7].kenmerk [relation: contains]
#   message.goods[7] -> message.goods[7].actie [relation: contains]
#   message.goods[7] -> message.goods[7].euroDV [relation: contains]
#   message.goods[7] -> message.goods[7].blokDV [relation: contains]
#   message.goods[7] -> message.goods[7].noOfColli [relation: contains]
#   message.goods[7] -> message.goods[7].unloadLocation [relation: contains]
#   message.goods[7].unloadLocation -> message.goods[7].unloadLocation.straat [relation: contains]
#   message.goods[7].unloadLocation -> message.goods[7].unloadLocation.naam [relation: contains]
#   message.goods[7].unloadLocation -> message.goods[7].unloadLocation.postcode [relation: contains]
#   message.goods[7].unloadLocation -> message.goods[7].unloadLocation.plaats [relation: contains]
#   message.goods[7].unloadLocation -> message.goods[7].unloadLocation.land [relation: contains]
#   message.goods[8] -> message.goods[8].kenmerk [relation: contains]
#   message.goods[8] -> message.goods[8].actie [relation: contains]
#   message.goods[8] -> message.goods[8].euroDV [relation: contains]
#   message.goods[8] -> message.goods[8].blokDV [relation: contains]
#   message.goods[8] -> message.goods[8].noOfColli [relation: contains]
#   message.goods[8] -> message.goods[8].unloadLocation [relation: contains]
#   message.goods[8].unloadLocation -> message.goods[8].unloadLocation.straat [relation: contains]
#   message.goods[8].unloadLocation -> message.goods[8].unloadLocation.naam [relation: contains]
#   message.goods[8].unloadLocation -> message.goods[8].unloadLocation.postcode [relation: contains]
#   message.goods[8].unloadLocation -> message.goods[8].unloadLocation.plaats [relation: contains]
#   message.goods[8].unloadLocation -> message.goods[8].unloadLocation.land [relation: contains]
#   message.goods[9] -> message.goods[9].kenmerk [relation: contains]
#   message.goods[9] -> message.goods[9].actie [relation: contains]
#   message.goods[9] -> message.goods[9].euroDV [relation: contains]
#   message.goods[9] -> message.goods[9].blokDV [relation: contains]
#   message.goods[9] -> message.goods[9].noOfColli [relation: contains]
#   message.goods[9] -> message.goods[9].unloadLocation [relation: contains]
#   message.goods[9].unloadLocation -> message.goods[9].unloadLocation.straat [relation: contains]
#   message.goods[9].unloadLocation -> message.goods[9].unloadLocation.naam [relation: contains]
#   message.goods[9].unloadLocation -> message.goods[9].unloadLocation.postcode [relation: contains]
#   message.goods[9].unloadLocation -> message.goods[9].unloadLocation.plaats [relation: contains]
#   message.goods[9].unloadLocation -> message.goods[9].unloadLocation.land [relation: contains]

# %%
def print_graph_as_tree(graph, root=None, level=0, visited=None):
    if visited is None:
        visited = set()

    if root is None:
        # Start with nodes that have no incoming edges (potential roots)
        roots = [n for n in graph.nodes if graph.in_degree(n) == 0]
        for r in roots:
            print_graph_as_tree(graph, r, level, visited)
        return

    # Print the current node with indentation
    indent = "  " * level
    print(f"{indent}- {root}: {graph.nodes[root]}")

    # Mark the node as visited to prevent cycles
    visited.add(root)

    # Recurse on neighbors (children)
    for neighbor in graph.successors(root):
        if neighbor not in visited:
            print_graph_as_tree(graph, neighbor, level + 1, visited)

# Display the graph as a tree
print("\nGraph as Tree:")
print_graph_as_tree(G)
# Out:
# Graph as Tree:
# - message: {'label': 'message', 'value': "{'externalShipmentId': 'ES24D44444444FXHCUHCT', 'contractCarriageCondition': 'NA', 'involvedActors': [{'actorAddress': None, 'actorId': 'D44444444', 'actorName': 'Company D', 'actorRoles': ['LogisticRoles_TransportOperator'], 'actorWebSite': None, 'actorEmail': 'Simple4shipment@gmail.com', 'actorPhoneNumber': None}, {'actorAddress': None, 'actorId': 'A11111111', 'actorName': 'Company B', 'actorRoles': ['LogisticRoles_Consignor'], 'actorWebSite': None, 'actorEmail': None, 'actorPhoneNumber': None}, {'actorAddress': None, 'actorId': 'B22222222', 'actorName': 'Company A', 'actorRoles': ['LogisticRoles_Consignee'], 'actorWebSite': None, 'actorEmail': 'Juavie10@gmail.com', 'actorPhoneNumber': None}, {'actorAddress': None, 'actorId': 'C33333333', 'actorName': 'Company C', 'actorRoles': ['LogisticRoles_DispatchParty'], 'actorWebSite': None, 'actorEmail': None, 'actorPhoneNumber': None}], 'origin': {'placeLocalization': {'addressName': None, 'addressNumber': None, 'location': {'zipCode': None, 'city': {'name': None, 'cityLoCode': 'ES MAD'}, 'country': {'name': None, 'unLoCode': 'ES'}}, 'roadType': None, 'terminalNode': None}, 'dateTimeType': {'dateTime': '2024-09-16T11:46:45.000+02:00', 'type': 'Estimated'}}, 'destination': {'placeLocalization': {'addressName': None, 'addressNumber': None, 'location': {'zipCode': None, 'city': {'name': None, 'cityLoCode': 'ES SVQ'}, 'country': {'name': None, 'unLoCode': 'ES'}}, 'roadType': None, 'terminalNode': None}, 'dateTimeType': {'dateTime': '2024-09-23T13:15:48.000+02:00', 'type': 'Estimated'}}, 'equipments': [{'equipmentId': 'JSVU12453627', 'equipmentType': {'code': 'CN', 'description': None}, 'wagonId': None, 'codeITU': '40', 'grossWeight': 42000, 'isEmpty': True, 'sealIndicator': 'Precxx3234', 'goods': [{'package': {'numberOfPackages': 26, 'shippingMark': 'bridgestones', 'packagingType': None}, 'goodTypeCode': 'tires', 'goodDescription': 'finished rubber tires', 'cargoType': 'Pallets', 'idNumberList': ['21321'], 'goodWeight': 0.0, 'goodGrossMass': 23000.0, 'goodSize': 12, 'temperature': None, 'dangerousGoods': False, 'dangerousGoodsDescription': None, 'damageRemarks': None}], 'damageRemarks': 'string', 'city': {'name': None, 'cityLoCode': 'ES MAD'}, 'country': None, 'dangerousEquipment': False, 'dangerousEquipmentDescription': None}], 'documents': [], 'externalReferences': [{'type': 'shipment_reference', 'id': 'BL112233', 'endPoint': None}]}"}
#   - message.externalShipmentId: {'label': 'externalShipmentId', 'value': 'ES24D44444444FXHCUHCT'}
#   - message.contractCarriageCondition: {'label': 'contractCarriageCondition', 'value': 'NA'}
#   - message.involvedActors: {'label': 'involvedActors', 'value': "[{'actorAddress': None, 'actorId': 'D44444444', 'actorName': 'Company D', 'actorRoles': ['LogisticRoles_TransportOperator'], 'actorWebSite': None, 'actorEmail': 'Simple4shipment@gmail.com', 'actorPhoneNumber': None}, {'actorAddress': None, 'actorId': 'A11111111', 'actorName': 'Company B', 'actorRoles': ['LogisticRoles_Consignor'], 'actorWebSite': None, 'actorEmail': None, 'actorPhoneNumber': None}, {'actorAddress': None, 'actorId': 'B22222222', 'actorName': 'Company A', 'actorRoles': ['LogisticRoles_Consignee'], 'actorWebSite': None, 'actorEmail': 'Juavie10@gmail.com', 'actorPhoneNumber': None}, {'actorAddress': None, 'actorId': 'C33333333', 'actorName': 'Company C', 'actorRoles': ['LogisticRoles_DispatchParty'], 'actorWebSite': None, 'actorEmail': None, 'actorPhoneNumber': None}]"}
#     - message.involvedActors[0]: {'label': 'involvedActors[0]', 'value': "{'actorAddress': None, 'actorId': 'D44444444', 'actorName': 'Company D', 'actorRoles': ['LogisticRoles_TransportOperator'], 'actorWebSite': None, 'actorEmail': 'Simple4shipment@gmail.com', 'actorPhoneNumber': None}"}
#       - message.involvedActors[0].actorId: {'label': 'actorId', 'value': 'D44444444'}
#       - message.involvedActors[0].actorName: {'label': 'actorName', 'value': 'Company D'}
#       - message.involvedActors[0].actorRoles: {'label': 'actorRoles', 'value': "['LogisticRoles_TransportOperator']"}
#         - message.involvedActors[0].actorRoles[0]: {'label': 'actorRoles[0]', 'value': 'LogisticRoles_TransportOperator'}
#       - message.involvedActors[0].actorEmail: {'label': 'actorEmail', 'value': 'Simple4shipment@gmail.com'}
#     - message.involvedActors[1]: {'label': 'involvedActors[1]', 'value': "{'actorAddress': None, 'actorId': 'A11111111', 'actorName': 'Company B', 'actorRoles': ['LogisticRoles_Consignor'], 'actorWebSite': None, 'actorEmail': None, 'actorPhoneNumber': None}"}
#       - message.involvedActors[1].actorId: {'label': 'actorId', 'value': 'A11111111'}
#       - message.involvedActors[1].actorName: {'label': 'actorName', 'value': 'Company B'}
#       - message.involvedActors[1].actorRoles: {'label': 'actorRoles', 'value': "['LogisticRoles_Consignor']"}
#         - message.involvedActors[1].actorRoles[0]: {'label': 'actorRoles[0]', 'value': 'LogisticRoles_Consignor'}
#     - message.involvedActors[2]: {'label': 'involvedActors[2]', 'value': "{'actorAddress': None, 'actorId': 'B22222222', 'actorName': 'Company A', 'actorRoles': ['LogisticRoles_Consignee'], 'actorWebSite': None, 'actorEmail': 'Juavie10@gmail.com', 'actorPhoneNumber': None}"}
#       - message.involvedActors[2].actorId: {'label': 'actorId', 'value': 'B22222222'}
#       - message.involvedActors[2].actorName: {'label': 'actorName', 'value': 'Company A'}
#       - message.involvedActors[2].actorRoles: {'label': 'actorRoles', 'value': "['LogisticRoles_Consignee']"}
#         - message.involvedActors[2].actorRoles[0]: {'label': 'actorRoles[0]', 'value': 'LogisticRoles_Consignee'}
#       - message.involvedActors[2].actorEmail: {'label': 'actorEmail', 'value': 'Juavie10@gmail.com'}
#     - message.involvedActors[3]: {'label': 'involvedActors[3]', 'value': "{'actorAddress': None, 'actorId': 'C33333333', 'actorName': 'Company C', 'actorRoles': ['LogisticRoles_DispatchParty'], 'actorWebSite': None, 'actorEmail': None, 'actorPhoneNumber': None}"}
#       - message.involvedActors[3].actorId: {'label': 'actorId', 'value': 'C33333333'}
#       - message.involvedActors[3].actorName: {'label': 'actorName', 'value': 'Company C'}
#       - message.involvedActors[3].actorRoles: {'label': 'actorRoles', 'value': "['LogisticRoles_DispatchParty']"}
#         - message.involvedActors[3].actorRoles[0]: {'label': 'actorRoles[0]', 'value': 'LogisticRoles_DispatchParty'}
#   - message.origin: {'label': 'origin', 'value': "{'placeLocalization': {'addressName': None, 'addressNumber': None, 'location': {'zipCode': None, 'city': {'name': None, 'cityLoCode': 'ES MAD'}, 'country': {'name': None, 'unLoCode': 'ES'}}, 'roadType': None, 'terminalNode': None}, 'dateTimeType': {'dateTime': '2024-09-16T11:46:45.000+02:00', 'type': 'Estimated'}}"}
#     - message.origin.placeLocalization: {'label': 'placeLocalization', 'value': "{'addressName': None, 'addressNumber': None, 'location': {'zipCode': None, 'city': {'name': None, 'cityLoCode': 'ES MAD'}, 'country': {'name': None, 'unLoCode': 'ES'}}, 'roadType': None, 'terminalNode': None}"}
#       - message.origin.placeLocalization.location: {'label': 'location', 'value': "{'zipCode': None, 'city': {'name': None, 'cityLoCode': 'ES MAD'}, 'country': {'name': None, 'unLoCode': 'ES'}}"}
#         - message.origin.placeLocalization.location.city: {'label': 'city', 'value': "{'name': None, 'cityLoCode': 'ES MAD'}"}
#           - message.origin.placeLocalization.location.city.cityLoCode: {'label': 'cityLoCode', 'value': 'ES MAD'}
#         - message.origin.placeLocalization.location.country: {'label': 'country', 'value': "{'name': None, 'unLoCode': 'ES'}"}
#           - message.origin.placeLocalization.location.country.unLoCode: {'label': 'unLoCode', 'value': 'ES'}
#     - message.origin.dateTimeType: {'label': 'dateTimeType', 'value': "{'dateTime': '2024-09-16T11:46:45.000+02:00', 'type': 'Estimated'}"}
#       - message.origin.dateTimeType.dateTime: {'label': 'dateTime', 'value': '2024-09-16T11:46:45.000+02:00'}
#       - message.origin.dateTimeType.type: {'label': 'type', 'value': 'Estimated'}
#   - message.destination: {'label': 'destination', 'value': "{'placeLocalization': {'addressName': None, 'addressNumber': None, 'location': {'zipCode': None, 'city': {'name': None, 'cityLoCode': 'ES SVQ'}, 'country': {'name': None, 'unLoCode': 'ES'}}, 'roadType': None, 'terminalNode': None}, 'dateTimeType': {'dateTime': '2024-09-23T13:15:48.000+02:00', 'type': 'Estimated'}}"}
#     - message.destination.placeLocalization: {'label': 'placeLocalization', 'value': "{'addressName': None, 'addressNumber': None, 'location': {'zipCode': None, 'city': {'name': None, 'cityLoCode': 'ES SVQ'}, 'country': {'name': None, 'unLoCode': 'ES'}}, 'roadType': None, 'terminalNode': None}"}
#       - message.destination.placeLocalization.location: {'label': 'location', 'value': "{'zipCode': None, 'city': {'name': None, 'cityLoCode': 'ES SVQ'}, 'country': {'name': None, 'unLoCode': 'ES'}}"}
#         - message.destination.placeLocalization.location.city: {'label': 'city', 'value': "{'name': None, 'cityLoCode': 'ES SVQ'}"}
#           - message.destination.placeLocalization.location.city.cityLoCode: {'label': 'cityLoCode', 'value': 'ES SVQ'}
#         - message.destination.placeLocalization.location.country: {'label': 'country', 'value': "{'name': None, 'unLoCode': 'ES'}"}
#           - message.destination.placeLocalization.location.country.unLoCode: {'label': 'unLoCode', 'value': 'ES'}
#     - message.destination.dateTimeType: {'label': 'dateTimeType', 'value': "{'dateTime': '2024-09-23T13:15:48.000+02:00', 'type': 'Estimated'}"}
#       - message.destination.dateTimeType.dateTime: {'label': 'dateTime', 'value': '2024-09-23T13:15:48.000+02:00'}
#       - message.destination.dateTimeType.type: {'label': 'type', 'value': 'Estimated'}
#   - message.equipments: {'label': 'equipments', 'value': "[{'equipmentId': 'JSVU12453627', 'equipmentType': {'code': 'CN', 'description': None}, 'wagonId': None, 'codeITU': '40', 'grossWeight': 42000, 'isEmpty': True, 'sealIndicator': 'Precxx3234', 'goods': [{'package': {'numberOfPackages': 26, 'shippingMark': 'bridgestones', 'packagingType': None}, 'goodTypeCode': 'tires', 'goodDescription': 'finished rubber tires', 'cargoType': 'Pallets', 'idNumberList': ['21321'], 'goodWeight': 0.0, 'goodGrossMass': 23000.0, 'goodSize': 12, 'temperature': None, 'dangerousGoods': False, 'dangerousGoodsDescription': None, 'damageRemarks': None}], 'damageRemarks': 'string', 'city': {'name': None, 'cityLoCode': 'ES MAD'}, 'country': None, 'dangerousEquipment': False, 'dangerousEquipmentDescription': None}]"}
#     - message.equipments[0]: {'label': 'equipments[0]', 'value': "{'equipmentId': 'JSVU12453627', 'equipmentType': {'code': 'CN', 'description': None}, 'wagonId': None, 'codeITU': '40', 'grossWeight': 42000, 'isEmpty': True, 'sealIndicator': 'Precxx3234', 'goods': [{'package': {'numberOfPackages': 26, 'shippingMark': 'bridgestones', 'packagingType': None}, 'goodTypeCode': 'tires', 'goodDescription': 'finished rubber tires', 'cargoType': 'Pallets', 'idNumberList': ['21321'], 'goodWeight': 0.0, 'goodGrossMass': 23000.0, 'goodSize': 12, 'temperature': None, 'dangerousGoods': False, 'dangerousGoodsDescription': None, 'damageRemarks': None}], 'damageRemarks': 'string', 'city': {'name': None, 'cityLoCode': 'ES MAD'}, 'country': None, 'dangerousEquipment': False, 'dangerousEquipmentDescription': None}"}
#       - message.equipments[0].equipmentId: {'label': 'equipmentId', 'value': 'JSVU12453627'}
#       - message.equipments[0].equipmentType: {'label': 'equipmentType', 'value': "{'code': 'CN', 'description': None}"}
#         - message.equipments[0].equipmentType.code: {'label': 'code', 'value': 'CN'}
#       - message.equipments[0].codeITU: {'label': 'codeITU', 'value': '40'}
#       - message.equipments[0].grossWeight: {'label': 'grossWeight', 'value': '42000'}
#       - message.equipments[0].isEmpty: {'label': 'isEmpty', 'value': 'True'}
#       - message.equipments[0].sealIndicator: {'label': 'sealIndicator', 'value': 'Precxx3234'}
#       - message.equipments[0].goods: {'label': 'goods', 'value': "[{'package': {'numberOfPackages': 26, 'shippingMark': 'bridgestones', 'packagingType': None}, 'goodTypeCode': 'tires', 'goodDescription': 'finished rubber tires', 'cargoType': 'Pallets', 'idNumberList': ['21321'], 'goodWeight': 0.0, 'goodGrossMass': 23000.0, 'goodSize': 12, 'temperature': None, 'dangerousGoods': False, 'dangerousGoodsDescription': None, 'damageRemarks': None}]"}
#         - message.equipments[0].goods[0]: {'label': 'goods[0]', 'value': "{'package': {'numberOfPackages': 26, 'shippingMark': 'bridgestones', 'packagingType': None}, 'goodTypeCode': 'tires', 'goodDescription': 'finished rubber tires', 'cargoType': 'Pallets', 'idNumberList': ['21321'], 'goodWeight': 0.0, 'goodGrossMass': 23000.0, 'goodSize': 12, 'temperature': None, 'dangerousGoods': False, 'dangerousGoodsDescription': None, 'damageRemarks': None}"}
#           - message.equipments[0].goods[0].package: {'label': 'package', 'value': "{'numberOfPackages': 26, 'shippingMark': 'bridgestones', 'packagingType': None}"}
#             - message.equipments[0].goods[0].package.numberOfPackages: {'label': 'numberOfPackages', 'value': '26'}
#             - message.equipments[0].goods[0].package.shippingMark: {'label': 'shippingMark', 'value': 'bridgestones'}
#           - message.equipments[0].goods[0].goodTypeCode: {'label': 'goodTypeCode', 'value': 'tires'}
#           - message.equipments[0].goods[0].goodDescription: {'label': 'goodDescription', 'value': 'finished rubber tires'}
#           - message.equipments[0].goods[0].cargoType: {'label': 'cargoType', 'value': 'Pallets'}
#           - message.equipments[0].goods[0].idNumberList: {'label': 'idNumberList', 'value': "['21321']"}
#             - message.equipments[0].goods[0].idNumberList[0]: {'label': 'idNumberList[0]', 'value': '21321'}
#           - message.equipments[0].goods[0].goodWeight: {'label': 'goodWeight', 'value': '0.0'}
#           - message.equipments[0].goods[0].goodGrossMass: {'label': 'goodGrossMass', 'value': '23000.0'}
#           - message.equipments[0].goods[0].goodSize: {'label': 'goodSize', 'value': '12'}
#           - message.equipments[0].goods[0].dangerousGoods: {'label': 'dangerousGoods', 'value': 'False'}
#       - message.equipments[0].damageRemarks: {'label': 'damageRemarks', 'value': 'string'}
#       - message.equipments[0].city: {'label': 'city', 'value': "{'name': None, 'cityLoCode': 'ES MAD'}"}
#         - message.equipments[0].city.cityLoCode: {'label': 'cityLoCode', 'value': 'ES MAD'}
#       - message.equipments[0].dangerousEquipment: {'label': 'dangerousEquipment', 'value': 'False'}
#   - message.documents: {'label': 'documents', 'value': '[]'}
#   - message.externalReferences: {'label': 'externalReferences', 'value': "[{'type': 'shipment_reference', 'id': 'BL112233', 'endPoint': None}]"}
#     - message.externalReferences[0]: {'label': 'externalReferences[0]', 'value': "{'type': 'shipment_reference', 'id': 'BL112233', 'endPoint': None}"}
#       - message.externalReferences[0].type: {'label': 'type', 'value': 'shipment_reference'}
#       - message.externalReferences[0].id: {'label': 'id', 'value': 'BL112233'}

# %%
csv_file_path = "graph_nodes.csv"

# Open the file and write the nodes
with open(csv_file_path, mode="w", newline="") as file:
    writer = csv.writer(file)
    
    # Write the header
    writer.writerow(["Node", "Attribute", "Value"])
    
    # Write each node with its attributes
    for node, attributes in G.nodes(data=True):
        for attr, value in attributes.items():
            writer.writerow([node, attr, value])

# %%
csv_file_path = "graph_deep_nodes.csv"

# Open the file and write the nodes
with open(csv_file_path, mode="w", newline="") as file:
    writer = csv.writer(file)
    
    # Write the header
    writer.writerow(["Node", "Attribute", "Value"])
    
    # Write each node with its attributes
    for node, attributes in G2.nodes(data=True):
        for attr, value in attributes.items():
            writer.writerow([node, attr, value])

# %%
unique_labels = set()

for node, attributes in Flowertrucks_G.nodes(data=True):
    if "label" in attributes and "value" in attributes:
        if not isinstance(attributes["value"], (dict, list)):
            unique_labels.add(attributes["label"])  # Add to set to ensure uniqueness

# Convert to a sorted list (optional)
unique_labels_list = sorted(unique_labels)

normalized_labels = set()
for label in unique_labels:
    # Use regex to remove the `[n]` part dynamically
    normalized_label = re.sub(r"\[\d+\]$", "", label)
    normalized_labels.add(normalized_label)  # Ensure uniqueness

# Convert to sorted list (optional, for readability)
normalized_labels_list = sorted(normalized_labels)

# Print the cleaned-up labels
print(normalized_labels_list)
# Out:
# ['actie', 'blokDV', 'euroDV', 'goods', 'kenmerk', 'land', 'loadingDate', 'loadingLocation', 'message', 'messageType', 'naam', 'noOfColli', 'plaats', 'postcode', 'shipment', 'shipper', 'straat', 'unloadLocation']
